# %% [markdown]
# # Scene Hierarchy
#
# TODO WIP

# %% [markdown]
# ## Paths

# %%
from robotodo.engines.isaac import Scene, Entity

scene = Scene.load(
    "https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/5.0/Isaac/Environments/Grid/default_environment.usd",
)

# %%
list(scene.traverse())
# Out:
# ['/',
#  '/OmniverseKit_Right',
#  '/OmniverseKit_Front',
#  '/World',
#  '/World/Looks',
#  '/World/Looks/theGrid',
#  '/World/Looks/theGrid/Shader',
#  '/World/GroundPlane',
#  '/World/GroundPlane/CollisionPlane',
#  '/World/SphereLight',
#  '/World/Environment',
#  '/World/Environment/Geometry',
#  '/OmniverseKit_Top',
#  '/Render',
#  '/Render/OmniverseKit',
#  '/Render/OmniverseKit/HydraTextures',
#  '/Render/OmniverseKit/HydraTextures/omni_kit_widget_viewport_ViewportTexture_0',
#  '/Render/OmniverseGlobalRenderSettings',
#  '/Render/Vars',
#  '/Render/Vars/LdrColor']

# %%
Entity.load(
    "/World/Mug",
    source="https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/5.0/Isaac/Props/Mugs/SM_Mug_A2.usd",
    scene=scene,
)
# Out:
# Entity(['/World/Mug'], scene=Scene())

# %% [markdown]
# TODO doc glob pattern

# %%
Entity.load(
    "/World/Mug{A,B,C}",
    source="https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/5.0/Isaac/Props/Mugs/SM_Mug_A2.usd",
    scene=scene,
)
# Out:
# Entity(['/World/MugA' '/World/MugB' '/World/MugC'], scene=Scene())

# %%
list(scene.traverse())
# Out:
# ['/',
#  '/OmniverseKit_Right',
#  '/OmniverseKit_Front',
#  '/World',
#  '/World/Looks',
#  '/World/Looks/theGrid',
#  '/World/Looks/theGrid/Shader',
#  '/World/GroundPlane',
#  '/World/GroundPlane/CollisionPlane',
#  '/World/SphereLight',
#  '/World/Environment',
#  '/World/Environment/Geometry',
#  '/World/Mug',
#  '/World/Mug/Looks',
#  '/World/Mug/Looks/M_Mug_A2',
#  '/World/Mug/Looks/M_Mug_A2/M_Mug_A1',
#  '/World/Mug/SM_Mug_A2',
#  '/World/MugA',
#  '/World/MugA/Looks',
#  '/World/MugA/Looks/M_Mug_A2',
#  '/World/MugA/Looks/M_Mug_A2/M_Mug_A1',
#  '/World/MugA/SM_Mug_A2',
#  '/World/MugB',
#  '/World/MugB/Looks',
#  '/World/MugB/Looks/M_Mug_A2',
#  '/World/MugB/Looks/M_Mug_A2/M_Mug_A1',
#  '/World/MugB/SM_Mug_A2',
#  '/World/MugC',
#  '/World/MugC/Looks',
#  '/World/MugC/Looks/M_Mug_A2',
#  '/World/MugC/Looks/M_Mug_A2/M_Mug_A1',
#  '/World/MugC/SM_Mug_A2',
#  '/OmniverseKit_Top',
#  '/Render',
#  '/Render/OmniverseKit',
#  '/Render/OmniverseKit/HydraTextures',
#  '/Render/OmniverseKit/HydraTextures/omni_kit_widget_viewport_ViewportTexture_0',
#  '/Render/OmniverseGlobalRenderSettings',
#  '/Render/Vars',
#  '/Render/Vars/LdrColor']

# %% [markdown]
# ## Spatial Transforms

# %% [markdown]
# TODO WIP
