# %% [markdown]
# # Scene: Interaction
#
# TODO WIP
#
# Proposed code example:
# ```python
# from robotodo.scenes.core import PandaLiftCubeScene
#
# scene = PandaLiftCubeScene()
#
# # robot: panda
# scene.panda.joints
# scene.panda.joint_qpos.spec
# scene.panda.joint_qpos.current = {...}
#
# # object: cube
# scene.cube.contacts
# @scene.cube.on_contact
# def _(contact):
#     print("yep", contact)
#
# scene.cube.pose
# @scene.cube.pose.on_change
# def _(old, new):
#     ...
# scene.cube.velocity
# scene.cube.mass
# scene.cube.inertia
#
# scene.cube.visuals # Geometry() ? displays in jupyter as 3d object
# scene.cube.collisions # Geometry() ?
#
# # interactive viewer
# # TODO interaction: mouse, vr (thru webxr)
# scene.viewer # displays the viewer in cell in jupyter; comms via jupyter
# scene.viewer.serve() # serves the viewer over http; returns url and (optionally) opens it in browser
#
# #
# scene.step()
# scene.render()
#
# @scene.on_step
# def _():
#     ...
# ```
