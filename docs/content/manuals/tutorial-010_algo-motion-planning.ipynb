# %% [markdown]
# # Controller: Motion Planning
#
# TODO WIP
#
# Proposed code example:
#
# Built-in
# ```python
# # -omit- scene setup
# # -omit- robot definition
# # -omit- object definition
# robot = ...
# some_object = ...
# qpos_target = robot.ik_planner(
#     link=...,
#     pose=some_object.pose,
# )
# qpos_waypoints = robot.path_planner(qpos_target)
#
# for qpos in qpos_waypoints:
#     robot.pd_controller(target=qpos)
#     # -or- with more params
#     # robot.pd_controller(target=qpos, damping=.5)
#     # -or-
#     # ...
#     robot.scene.step()
# ```
#
# External
# ```python
# from robotodo.controllers.curobo import MotionPlanner
#
# planner = MotionPlanner(robot)
# planner(qpos_target)
# ```
