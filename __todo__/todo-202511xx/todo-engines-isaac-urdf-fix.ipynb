# %%
from robotodo.engines.isaac._kernel import configure_default_kernel, get_default_kernel
configure_default_kernel(
    extra_argv=[
        "--/app/enableStdoutOutput=true",
        "--/log/file=/tmp/todo-isaacsim-urdf-fix.log",
    ], 
)

# %%
# TODO 
from robotodo.engines.isaac.scene import Scene

scene = Scene.load(
    "https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/5.0/Isaac/Environments/Grid/default_environment.usd",
)
# scene.autostepping = True
# Out:
# [Warning] [simulation_app] Interactive python shell detected but ISAAC_JUPYTER_KERNEL was not set. Problems with asyncio may occur
# [Warning] [simulation_app] Please use Isaac Sim Python 3 kernel instead of the default Python 3 Kernel
# [0.031s] [ext: omni.kit.async_engine-0.0.3] startup
# [0.164s] [ext: omni.metrics.core-0.0.3] startup
# [0.164s] [ext: omni.client.lib-1.1.0] startup
# [0.178s] [ext: omni.blobkey-1.1.2] startup
# [0.179s] [ext: omni.stats-1.0.1] startup
# [0.180s] [ext: omni.datastore-0.0.0] startup
# [0.185s] [ext: omni.client-1.3.0] startup
# [0.240s] [ext: omni.ujitso.default-1.0.0] startup
# [0.242s] [ext: omni.hsscclient-1.1.2] startup
# [0.245s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.247s] [ext: omni.assets.plugins-0.0.0] startup
# [0.248s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.257s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.263s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 535.247.01    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 3090          | Yes: 0 |     | 24576   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2204      | 3b061d17.. |
# |     |                                  |        |     |            | 1         |            |
# |=============================================================================================|
# | OS: 12 (bookworm) debian, Version: 12.00.0, Kernel: 6.1.0-39-amd64
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101007 (1.21.1.7)
# | Processor: 12th Gen Intel(R) Core(TM) i5-12400F
# | Cores: 6 | Logical Cores: 12
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 64139 | Free Memory: 37473
# | Total Page/Swap (MB): 16383 | Free Page/Swap: 11562
# |---------------------------------------------------------------------------------------------|
# [0.794s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.795s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.795s] [ext: omni.materialx.libs-1.0.7] startup
# [0.802s] [ext: omni.pip.compute-1.6.3] startup
# [0.802s] [ext: omni.usd.config-1.0.6] startup
# [0.805s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.807s] [ext: omni.usd.libs-1.0.1] startup
# [0.899s] [ext: omni.kit.loop-isaac-1.3.7] startup
# [0.900s] [ext: omni.kit.test-2.0.1] startup
# [0.926s] [ext: omni.mdl-56.0.3] startup
# [0.946s] [ext: omni.iray.libs-0.0.0] startup
# [0.950s] [ext: omni.mdl.neuraylib-0.2.12] startup
# [0.952s] [ext: omni.kit.usd.mdl-1.1.5] startup
# [1.042s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.048s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.050s] [ext: omni.pip.cloud-1.4.3] startup
# [1.052s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.058s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.061s] [ext: omni.usd.schema.anim-0.0.0] startup
# [1.080s] [ext: omni.usd.schema.physx-107.3.26] startup
# [1.110s] [ext: omni.usd_resolver-1.0.0] startup
# [1.114s] [ext: omni.usd.core-1.5.3] startup
# [1.116s] [ext: omni.usd.schema.omni_sensors-0.0.0] startup
# [1.137s] [ext: omni.kit.actions.core-1.0.0] startup
# [1.139s] [ext: omni.appwindow-1.1.10] startup
# [1.142s] [ext: omni.kit.commands-1.4.10] startup
# [1.145s] [ext: omni.kit.renderer.core-1.1.0] startup
# [1.266s] [ext: omni.convexdecomposition-107.3.26] startup
# [1.269s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [1.271s] [ext: omni.kvdb-107.3.26] startup
# [1.273s] [ext: omni.kit.renderer.imgui-2.0.5] startup
# [1.343s] [ext: omni.localcache-107.3.26] startup
# [1.345s] [ext: omni.ui-2.27.1] startup
# [1.355s] [ext: omni.graph.tools-1.79.2] startup
# [1.417s] [ext: omni.kit.widget.graph-2.0.0] startup
# [1.424s] [ext: carb.audio-0.1.0] startup
# [1.427s] [ext: omni.hydra.scene_delegate-0.3.4] startup
# [1.432s] [ext: omni.kit.graph.delegate.default-1.2.3] startup
# [1.432s] [ext: omni.kit.audiodeviceenum-1.0.2] startup
# [1.434s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [1.436s] [ext: omni.activity.core-1.0.3] startup
# [1.438s] [ext: omni.resourcemonitor-107.0.1] startup
# [1.440s] [ext: omni.graph.exec-0.9.6] startup
# [1.440s] [ext: usdrt.scenegraph-7.6.1] startup
# [1.476s] [ext: omni.kit.widget.nucleus_connector-2.0.1] startup
# [1.477s] [ext: omni.timeline-1.0.14] startup
# [1.479s] [ext: omni.kit.usd_undo-0.1.8] startup
# [1.479s] [ext: omni.kit.exec.core-0.13.4] startup
# [1.480s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [1.487s] [ext: omni.ujitso.client-0.0.0] startup
# [1.488s] [ext: omni.usd-1.13.10] startup
# [1.508s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [1.509s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [1.543s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [1.546s] [ext: omni.usdphysics-107.3.26] startup
# [1.548s] [ext: omni.kit.helper.file_utils-0.1.9] startup
# [1.550s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [1.552s] [ext: omni.index.libs-380600.8087.0] startup
# [1.552s] [ext: omni.kit.widget.filebrowser-2.12.3] startup
# [1.556s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [1.557s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [1.558s] [ext: omni.index-1.0.1] startup
# [1.559s] [ext: omni.kit.menu.core-1.1.2] startup
# [1.559s] [ext: omni.kit.clipboard-1.0.5] startup
# [1.560s] [ext: omni.kit.widget.path_field-2.0.11] startup
# [1.561s] [ext: omni.kit.usd.layers-2.2.11] startup
# [1.569s] [ext: omni.kit.widget.context_menu-1.2.5] startup
# [1.570s] [ext: omni.volume-0.5.2] startup
# [1.573s] [ext: omni.ui.scene-1.11.5] startup
# [1.577s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [1.577s] [ext: omni.kit.notification_manager-1.0.10] startup
# [1.579s] [ext: omni.kit.context_menu-1.8.6] startup
# [1.580s] [ext: omni.hydra.rtx-1.0.0] startup
# [1.617s] [ext: omni.kit.window.filepicker-2.13.4] startup
# [1.627s] [ext: omni.kit.menu.utils-2.0.5] startup
# [1.633s] [ext: omni.kit.hydra_texture-1.4.6] startup
# [1.637s] [ext: omni.kit.widget.settings-1.2.6] startup
# [1.639s] [ext: omni.kit.window.file_exporter-1.0.33] startup
# [1.641s] [ext: omni.kit.widget.filter-1.1.4] startup
# [1.642s] [ext: omni.kit.hotkeys.core-1.3.10] startup
# [1.643s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [1.644s] [ext: omni.kit.window.preferences-1.8.0] startup
# [1.648s] [ext: omni.kit.widget.stage-3.1.4] startup
# [1.657s] [ext: omni.kit.material.library-2.0.7] startup
# [1.663s] [ext: omni.physx.foundation-107.3.26] startup
# [1.665s] [ext: omni.kit.window.material_graph-1.9.1] startup
# [1.673s] [ext: omni.inspect-1.0.2] startup
# [1.675s] [ext: omni.physx.cooking-107.3.26] startup
# [1.678s] [ext: omni.graph.core-2.184.5] startup
# [1.680s] [ext: omni.physx-107.3.26] startup
# [1.691s] [ext: omni.physics-107.3.26] startup
# [1.694s] [ext: omni.graph-1.141.2] startup
# [1.736s] [ext: omni.physics.physx-107.3.26] startup
# [1.738s] [ext: omni.graph.scriptnode-1.50.0] startup
# [1.739s] [ext: omni.warp.core-1.8.2] startup
# [1.974s] [ext: omni.hydra.engine.stats-1.0.3] startup
# [1.978s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [1.980s] [ext: omni.graph.action_core-1.1.7] startup
# [1.981s] [ext: omni.graph.image.core-0.6.1] startup
# [1.982s] [ext: omni.kit.widget.viewport-107.1.3] startup
# [1.985s] [ext: omni.graph.action_nodes_core-1.2.0] startup
# [1.987s] [ext: omni.graph.image.nodes-1.3.1] startup
# [1.988s] [ext: omni.kit.viewport.window-107.2.0] startup
# [2.007s] [ext: omni.graph.action_nodes-1.51.0] startup
# [2.010s] [ext: omni.graph.nodes_core-1.1.0] startup
# [2.016s] [ext: omni.kit.viewport.utility-1.1.2] startup
# [2.017s] [ext: omni.graph.action-1.130.0] startup
# [2.018s] [ext: omni.graph.nodes-1.171.0] startup
# [2.025s] [ext: omni.graph.ui_nodes-1.50.8] startup
# [2.036s] [ext: omni.syntheticdata-0.6.13] startup
# [2.122s] [ext: omni.videoencoding-0.1.2] startup
# [2.125s] [ext: omni.warp-1.8.2] startup
# [2.132s] [ext: omni.physics.stageupdate-107.3.26] startup
# [2.143s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [2.151s] [ext: omni.physics.tensors-107.3.26] startup
# [2.160s] [ext: omni.replicator.core-1.12.27] startup
# 2025-12-03T02:34:00Z [2,056ms] [Error] [omni.syntheticdata.scripts.extension] SyntheticData extension needs at least a stageFrameHistoryCount of 3
# Warp 1.8.2 initialized:
#    CUDA Toolkit 12.8, Driver 12.2
#    Devices:
#      "cpu"      : "CPU"
#      "cuda:0"   : "NVIDIA GeForce RTX 3090" (24 GiB, sm_86, mempool enabled)
#    Kernel cache:
#      /home/sysadmin/.cache/warp/1.8.2
# [2.340s] [ext: omni.physx.tensors-107.3.26] startup
# [2.347s] [ext: omni.kit.manipulator.camera-106.0.4] startup
# Warp DeprecationWarning: The `warp.sim` module is deprecated and will be removed in v1.10. Please transition to using the forthcoming Newton library instead.
# [2.925s] app ready
# 2025-12-03T02:34:02Z [4,020ms] [Error] [carb.graphics-vulkan.plugin] Could not get NGX parameters block because NGX isn't enabled.
# 2025-12-03T02:34:02Z [4,020ms] [Error] [carb.graphics-vulkan.plugin] Failed to create NGX context.
# 2025-12-03T02:34:02Z [4,108ms] [Error] [rtx.optixdenoising73.plugin] Failed to create an Optix adaptor for device 0

# %%
from robotodo.engines.isaac.articulation import Articulation

panda = Articulation.load(
    "/TODOPanda{0..2}",
    "/home/sysadmin/lab/robotodo/__todo__/todo-202510xx-misc/todo-curobo-sample-configs/franka/franka_description/franka_panda.urdf",
    scene=scene,
)
# Out:
# [7.473s] [ext: omni.kit.mainwindow-1.0.3] startup
# [7.489s] [ext: omni.uiaudio-1.0.0] startup
# [7.490s] [ext: omni.kit.uiapp-0.0.0] startup
# [7.491s] [ext: isaacsim.robot.schema-3.6.0] startup
# [7.501s] [ext: omni.kit.asset_converter-5.0.17] startup
# [7.514s] [ext: omni.kit.window.drop_support-1.0.5] startup
# [7.515s] [ext: omni.ui_query-1.1.8] startup
# [7.516s] [ext: omni.kit.ui_test-1.3.7] startup
# [7.518s] [ext: omni.kit.window.file_importer-1.1.18] startup
# [7.519s] [ext: omni.kit.widget.highlight_label-1.0.3] startup
# [7.521s] [ext: omni.kit.window.file-2.0.5] startup
# [7.524s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [7.525s] [ext: omni.kit.window.content_browser-3.1.3] startup
# [7.542s] [ext: omni.kit.property.adapter.core-1.0.2] startup
# [7.544s] [ext: omni.kit.window.property-1.12.1] startup
# [7.553s] [ext: omni.kit.property.adapter.usd-1.0.2] startup
# [7.554s] [ext: omni.kit.property.adapter.fabric-1.0.3] startup
# [7.556s] [ext: omni.kit.property.usd-4.5.12] startup
# [7.569s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [7.570s] [ext: omni.kit.usd.collect-2.4.5] startup
# [7.574s] [ext: omni.kit.usdz_export-1.0.9] startup
# [7.576s] [ext: omni.kit.tool.asset_importer-5.1.1] startup
# [7.587s] [ext: omni.kit.widget.zoombar-1.0.7] startup
# [7.589s] [ext: omni.kit.manipulator.viewport-107.0.1] startup
# [7.590s] [ext: omni.kit.browser.core-2.3.16] startup
# [7.594s] [ext: omni.kit.window.extensions-1.4.27] startup
# [7.606s] [ext: omni.graph.visualization.nodes-2.1.3] startup
# [7.623s] [ext: omni.kit.browser.folder.core-1.10.10] startup
# [7.629s] [ext: isaacsim.gui.components-1.2.1] startup
# [7.634s] [ext: isaacsim.examples.browser-0.2.1] startup
# [7.643s] [ext: isaacsim.asset.importer.urdf-2.4.30] startup
# [8.097s] [ext: omni.usd.schema.metrics.assembler-107.3.1] startup
# [8.101s] [ext: omni.usd.metrics.assembler-107.3.1] startup
# /home/sysadmin/lab/robotodo/packages/robotodo/engines/isaac/_utils/usd.py:154: UserWarning: TODO: Usd.Stage.Open(rootLayer=Sdf.Find('https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/5.0/Isaac/Environments/Grid/default_environment.usd'), sessionLayer=Sdf.Find('anon:0x2a74b500:default_environment-session.usda'), pathResolverContext=<invalid repr>) Sdf.Find('anon:0x324bb170:.usda')
#   warnings.warn(f"TODO: {stage} {sdf_layer}")

# %%
scene.autostepping = True

# %%
from robotodo.utils.pose import Pose

panda.pose = Pose([[0, 0, 0], [0, 2, 0], [0, 4, 0]])

# %%
panda.dof_positions = 1
# panda.driver.dof_target_positions = 1

# %%
# %%timeit -n 1

panda.dof_positions
# Out:
# The slowest run took 4.08 times longer than the fastest. This could mean that an intermediate result is being cached.
# 319 μs ± 204 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
planner = panda.planner(
    base_link="panda_link0",
    end_link="panda_hand",

    # base_link="base_link",
    # end_link="ee_link",

    # use_self_collision=True,
    # use_world_collision=True,
    
    # _curobo_motiongen_config=dict(
    #     # self_collision_check=False
    # ),
)

# %%
from robotodo.utils.pose import Pose

await panda.driver.execute_action(
    # TODO
    planner.compute_action({"target_pose_from_base": Pose([.5, .2, .5])}),
    position_error_limit=1,
    velocity_error_limit=1,
)
# Out:
# Batch mode enable graph is only supported with num_graph_seeds==1
# changing goal type, cuda graph reset not available, consider updating to cuda >= 12.0
# NoneType: None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/lab/robotodo/packages/robotodo/algos/motion_planning/reach.py:415, in MotionPlanner.compute_action(self, observation)
#     413 try:
#     414     # TODO .plan_batch_env for batch collisions
# --> 415     plan_result = self._curobo_motion_gen.plan_batch(
#     416         start_state=CuroboJointState.from_position(
#     417             position=torch.as_tensor(dof_positions, dtype=torch.float32).cuda(),
#     418         ),
#     419         goal_pose=CuroboPose(
#     420             position=torch.as_tensor(target_pose_p, dtype=torch.float32).cuda(),
#     421             # TODO use named wxyz
#     422             quaternion=torch.as_tensor(target_pose_q, dtype=torch.float32).cuda()
#     423                 [..., [3, 0, 1, 2]],
#     424         ),
#     425         # plan_config=MotionGenPlanConfig(num_graph_seeds=1, enable_graph=False, max_attempts=100),
#     426         # plan_config=MotionGenPlanConfig(
#     427         #     # num_graph_seeds=1,
#     428         #     # TODO this doesnt seem to do anything
#     429         #     # check_start_validity=False
#     430         # ),
#     431     )
#     432 except Exception as error:
#
# File ~/lab/curobo/src/curobo/wrap/reacher/motion_gen.py:1649, in MotionGen.plan_batch(self, start_state, goal_pose, plan_config, link_poses)
#    1645 solve_state = self._get_solve_state(
#    1646     ReacherSolveType.BATCH, plan_config, goal_pose, start_state
#    1647 )
# -> 1649 result = self._plan_batch_attempts(
#    1650     solve_state,
#    1651     start_state,
#    1652     goal_pose,
#    1653     plan_config,
#    1654     link_poses=link_poses,
#    1655 )
#    1656 return result
#
# File ~/lab/curobo/src/curobo/wrap/reacher/motion_gen.py:3194, in MotionGen._plan_batch_attempts(self, solve_state, start_state, goal_pose, plan_config, link_poses)
#    3193 for n in range(plan_config.max_attempts):
# -> 3194     result = self._plan_from_solve_state_batch(
#    3195         solve_state,
#    3196         start_state,
#    3197         goal_pose,
#    3198         plan_config,
#    3199         link_poses=link_poses,
#    3200     )
#    3202     time_dict["solve_time"] += result.solve_time
#
# File ~/lab/curobo/src/curobo/wrap/reacher/motion_gen.py:3859, in MotionGen._plan_from_solve_state_batch(self, solve_state, start_state, goal_pose, plan_config, link_poses)
#    3858 # plan ik:
# -> 3859 ik_result = self._solve_ik_from_solve_state(
#    3860     goal_pose,
#    3861     solve_state,
#    3862     start_state,
#    3863     plan_config.use_nn_ik_seed,
#    3864     plan_config.partial_ik_opt,
#    3865     link_poses,
#    3866 )
#    3868 if not plan_config.enable_graph and plan_config.partial_ik_opt:
#
# File ~/lab/robotodo/.conda/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      80 with self._recreate_cm():
# ---> 81     return func(*args, **kwds)
#
# File ~/lab/curobo/src/curobo/wrap/reacher/motion_gen.py:2820, in MotionGen._solve_ik_from_solve_state(self, goal_pose, solve_state, start_state, use_nn_seed, partial_ik_opt, link_poses)
#    2819     newton_iters = self.partial_ik_iters
# -> 2820 ik_result = self.ik_solver.solve_any(
#    2821     solve_state.solve_type,
#    2822     goal_pose,
#    2823     start_state.position.view(-1, self._dof),
#    2824     start_state.position.view(-1, 1, self._dof),
#    2825     solve_state.num_trajopt_seeds,
#    2826     solve_state.num_ik_seeds,
#    2827     use_nn_seed,
#    2828     newton_iters,
#    2829     link_poses,
#    2830 )
#    2831 return ik_result
#
# File ~/lab/curobo/src/curobo/wrap/reacher/ik_solver.py:1211, in IKSolver.solve_any(self, solve_type, goal_pose, retract_config, seed_config, return_seeds, num_seeds, use_nn_seed, newton_iters, link_poses)
#    1210 elif solve_type == ReacherSolveType.BATCH:
# -> 1211     return self.solve_batch(
#    1212         goal_pose,
#    1213         retract_config,
#    1214         seed_config,
#    1215         return_seeds,
#    1216         num_seeds,
#    1217         use_nn_seed,
#    1218         newton_iters,
#    1219         link_poses,
#    1220     )
#    1221 elif solve_type == ReacherSolveType.BATCH_GOALSET:
#
# File ~/lab/curobo/src/curobo/wrap/reacher/ik_solver.py:823, in IKSolver.solve_batch(self, goal_pose, retract_config, seed_config, return_seeds, num_seeds, use_nn_seed, newton_iters, link_poses)
#     816 solve_state = ReacherSolveState(
#     817     ReacherSolveType.BATCH,
#     818     num_ik_seeds=num_seeds,
#    (...)    821     n_goalset=1,
#     822 )
# --> 823 return self._solve_from_solve_state(
#     824     solve_state,
#     825     goal_pose,
#     826     num_seeds,
#     827     retract_config,
#     828     seed_config,
#     829     return_seeds,
#     830     use_nn_seed,
#     831     newton_iters,
#     832     link_poses=link_poses,
#     833 )
#
# File ~/lab/curobo/src/curobo/wrap/reacher/ik_solver.py:1066, in IKSolver._solve_from_solve_state(self, solve_state, goal_pose, num_seeds, retract_config, seed_config, return_seeds, use_nn_seed, newton_iters, link_poses)
#    1065 # create goal buffer:
# -> 1066 goal_buffer = self._update_goal_buffer(solve_state, goal_pose, retract_config, link_poses)
#    1067 coord_position_seed = self.get_seed(
#    1068     num_seeds, goal_buffer.goal_pose, use_nn_seed, seed_config
#    1069 )
#
# File ~/lab/curobo/src/curobo/wrap/reacher/ik_solver.py:613, in IKSolver._update_goal_buffer(self, solve_state, goal_pose, retract_config, link_poses)
#     612     else:
# --> 613         log_error(
#     614             "changing goal type, cuda graph reset not available, "
#     615             + "consider updating to cuda >= 12.0"
#     616         )
#     618 self.solver.update_nproblems(self._solve_state.get_ik_batch_size())
#
# File ~/lab/curobo/src/curobo/util/logger.py:103, in log_error(txt, logger_name, exc_info, stack_info, stacklevel, *args, **kwargs)
#     100     logger.error(
#     101         txt, exc_info=exc_info, stack_info=stack_info, stacklevel=stacklevel, *args, **kwargs
#     102     )
# --> 103 raise ValueError(txt)
#
# ValueError: changing goal type, cuda graph reset not available, consider updating to cuda >= 12.0
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 5
#       1 from robotodo.utils.pose import Pose
#       3 await panda.driver.execute_action(
#       4     # TODO
# ----> 5     planner.compute_action({"target_pose_from_base": Pose([.5, .2, .5])}),
#       6     position_error_limit=1,
#       7     velocity_error_limit=1,
#       8 )
#
# File ~/lab/robotodo/packages/robotodo/engines/isaac/articulation.py:986, in ArticulationPlanner.compute_action(self, observation)
#     980         raise ValueError("TODO")
#     981     target_pose_from_base = (
#     982         self._articulation.links[self._backend.base_link].pose.inv()
#     983         * target_pose
#     984     )
# --> 986 return self._backend.compute_action({
#     987     "dof_positions": dof_positions,
#     988     "target_pose": target_pose_from_base,
#     989 })
#
# File ~/lab/robotodo/packages/robotodo/algos/motion_planning/reach.py:433, in MotionPlanner.compute_action(self, observation)
#     415     plan_result = self._curobo_motion_gen.plan_batch(
#     416         start_state=CuroboJointState.from_position(
#     417             position=torch.as_tensor(dof_positions, dtype=torch.float32).cuda(),
#    (...)    430         # ),
#     431     )
#     432 except Exception as error:
# --> 433     raise RuntimeError(
#     434         f"An error occurred while planning: are the DOF positions valid?"
#     435     ) from error
#     437 # TODO
#     438 # plan_result.interpolated_plan.position
#     439 # plan_result.interpolated_plan.velocity
#     441 if plan_result.optimized_plan is None:
#
# RuntimeError: An error occurred while planning: are the DOF positions valid?

# %%
from robotodo.engines.isaac._kernel import Kernel
from robotodo.engines.isaac._utils.usd import usd_add_reference

import os
import tempfile


def usd_import_urdf(
    stage: "pxr.Usd.Stage",
    path: str,
    resource_or_model: str,
    kernel: Kernel,
):
    pxr = kernel.pxr
    isaacsim = kernel.isaacsim
    # TODO rm
    import isaacsim.asset.importer.urdf

    with tempfile.TemporaryDirectory() as tmpdir:
        usd_path = os.path.join(tmpdir, "todo.usd")

        urdf_import_config = isaacsim.asset.importer.urdf.URDFCreateImportConfig().do()
        urdf_import_config.make_default_prim = True  # Make the robot the default prim in the scene
        # import_config.fix_base = config.get("fix_root_link", False) # Fix the base of the robot to the ground
        urdf_import_config.merge_fixed_joints = False
        # import_config.convex_decomp = False  # Disable convex decomposition for simplicity
        # import_config.self_collision = False  # Disable self-collision for performance

        isaacsim.asset.importer.urdf.URDFParseAndImportFile(
            urdf_path=resource_or_model,
            # TODO
            import_config=urdf_import_config,
            dest_path=usd_path,
        ).do()

        # TODO NOTE this alt impl does not respect merge_fixed_joints due to a bug?
        # urdf_robot_model = isaacsim.asset.importer.urdf.URDFParseFile(
        #     resource_or_model,
        #     import_config=urdf_import_config,
        # ).do()
        # isaacsim.asset.importer.urdf.URDFImportRobot(
        #     urdf_robot=urdf_robot_model,
        #     dest_path=usd_path,
        # ).do()

        layer = pxr.Usd.Stage.Open(usd_path).Flatten()

        return usd_add_reference(
            stage,
            path=path,
            # resource=usd_path,
            resource=layer.identifier,
            kernel=kernel,
        )

# %%
usd_import_urdf(
    scene._usd_stage,
    "/todo2",
    "/home/sysadmin/lab/robotodo/__todo__/todo-202510xx-misc/todo-curobo-sample-configs/franka/franka_description/franka_panda.urdf",
    kernel=scene._kernel,
)
# Out:
# Usd.Prim(</todo2>)

# %%
scene.load("/tmp/tmpaf2fccao/todo.usd")
# Out:
# Scene()
# 2025-11-27T11:28:51Z [1,837,081ms] [Error] [omni.physicsschema.plugin] Joint (/panda/joints/panda_finger_joint1) body relationship /panda/panda_hand points to a non existent prim, joint will not be created.
# 2025-11-27T11:28:51Z [1,837,081ms] [Error] [omni.physicsschema.plugin] Joint (/panda/joints/panda_finger_joint2) body relationship /panda/panda_hand points to a non existent prim, joint will not be created.
# 2025-11-27T11:28:51Z [1,837,081ms] [Error] [omni.physicsschema.plugin] Joint (/panda/joints/panda_joint1) body relationship /panda/panda_link0 points to a non existent prim, joint will not be created.

# %%
import weakref

import os
import tempfile


_todo_weakrefs = weakref.WeakValueDictionary()

def todo(stage):
    tmpdir = tempfile.TemporaryDirectory()
    usd_path = os.path.join(tmpdir.name, "todo.usd")
    # _todo_weakrefs[tmpdir] = stage
    # stage._todo = tmpdir
    return tmpdir.name

todo(scene._usd_stage)
# Out:
# '/tmp/tmpux9n13t8'

# %%
import os
import tempfile

tmpdir = tempfile.TemporaryDirectory()
# usd_path = os.path.join(tmpdir, "todo.usd")

tmpdir
# Out:
# <TemporaryDirectory '/tmp/tmp63voxr_k'>

# %%
import isaacsim.asset.importer.urdf

urdf_robot_model = isaacsim.asset.importer.urdf.URDFParseFile(
    "/home/sysadmin/lab/robotodo/__todo__/todo-202510xx-misc/todo-curobo-sample-configs/franka/franka_description/franka_panda.urdf"
).do()

isaacsim.asset.importer.urdf.URDFImportRobot(
    urdf_robot=urdf_robot_model,
    dest_path="/tmp/todo-robot/todo.usd",
).do()
# Out:
# '/panda'
