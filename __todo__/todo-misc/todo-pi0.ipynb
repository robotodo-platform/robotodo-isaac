# %%
# %load_ext autoreload
# %autoreload complete

# %%
from robotodo.algos.pi0 import Pi0Controller

# %%
pi0_controller = Pi0Controller()
# Out:
# Could not load symbol cuFuncGetName. Error: /usr/lib/x86_64-linux-gnu/libcuda.so.1: undefined symbol: cuFuncGetName

# %%
pi0_controller.compute_action(
    pi0_controller.observation_spec.random()
)
# Out:
# {('joint', 0): array([[0.72436804]]),
#  ('joint', 1): array([[2.36428905]]),
#  ('joint', 2): array([[-2.10792971]]),
#  ('joint', 3): array([[0.7766977]]),
#  ('joint', 4): array([[1.12390792]]),
#  ('joint', 5): array([[-1.374295]]),
#  ('joint', 6): array([[-1.62030804]]),
#  ('joint', 7): array([[-0.51389498]]),
#  ('joint', 8): array([[-0.92527801]]),
#  ('joint', 9): array([[-3.01997137]]),
#  ('joint', 10): array([[2.71197534]]),
#  ('joint', 11): array([[-1.22902262]]),
#  ('joint', 12): array([[-0.93620753]]),
#  ('joint', 13): array([[0.85160887]]),
#  ('joint', 14): array([[1.41382909]]),
#  ('joint', 15): array([[0.9670397]]),
#  ('joint', 16): array([[1.1598177]]),
#  ('joint', 17): array([[-0.24254298]]),
#  ('joint', 18): array([[-0.53907186]]),
#  ('joint', 19): array([[-4.21358728]]),
#  ('joint', 20): array([[-2.82675743]]),
#  ('joint', 21): array([[1.0506413]]),
#  ('joint', 22): array([[-0.45792452]]),
#  ('joint', 23): array([[1.66089284]]),
#  ('joint', 24): array([[0.36225075]]),
#  ('joint', 25): array([[1.54606915]]),
#  ('joint', 26): array([[1.9865098]]),
#  ('joint', 27): array([[1.59810257]]),
#  ('joint', 28): array([[-0.04964646]]),
#  ('joint', 29): array([[-0.33514869]]),
#  ('joint', 30): array([[-1.19014621]]),
#  ('joint', 31): array([[0.34020603]])}
