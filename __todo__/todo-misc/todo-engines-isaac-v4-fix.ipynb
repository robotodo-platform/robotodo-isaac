# %%
from robotodo.engines.isaac._kernel import Kernel

kernel = Kernel(["--no-window"])
# Out:
# [Warning] [simulation_app] Interactive python shell detected but ISAAC_JUPYTER_KERNEL was not set. Problems with asyncio may occur
# [Warning] [simulation_app] Please use Isaac Sim Python 3 kernel instead of the default Python 3 Kernel
# Loading user config located at: '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Full/5.0/user.config.json'
# 2025-09-16T02:05:05Z s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [0.179s] [ext: omni.kit.async_engine-0.0.3] startup
# [0.861s] [ext: omni.metrics.core-0.0.3] startup
# [0.862s] [ext: omni.client.lib-1.1.0] startup
# [0.962s] [ext: omni.blobkey-1.1.2] startup
# [0.962s] [ext: omni.stats-1.0.1] startup
# [0.965s] [ext: omni.datastore-0.0.0] startup
# [1.013s] [ext: omni.client-1.3.0] startup
# [1.090s] [ext: omni.ujitso.default-1.0.0] startup
# [1.094s] [ext: omni.hsscclient-1.1.2] startup
# ...

# %%
kernel.start_app_loop_soon()
# Out:
# [15.253s] [ext: isaacsim.ros2.bridge-4.9.3] startup
# 2025-09-16T02:05:20Z [15,323ms] [Warning] [isaacsim.ros2.bridge.impl.extension] ROS_DISTRO env var not found, Please source ROS before enabling this extension
# [15.355s] Using backup internal ROS2 humble distro
# [15.400s] To use the internal libraries included with the extension please set the following environment variables to use with FastDDS (default) or CycloneDDS before starting Isaac Sim:
#
# FastDDS (default):
# export ROS_DISTRO=humble
# export RMW_IMPLEMENTATION=rmw_fastrtps_cpp
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/isaacsim/exts/isaacsim.ros2.bridge/humble/lib
#
# OR
#
# CycloneDDS:
# export ROS_DISTRO=humble
# export RMW_IMPLEMENTATION=rmw_cyclonedds_cpp
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/isaacsim/exts/isaacsim.ros2.bridge/humble/lib
#
#
# ...

# %%
import omni

omni.ext.get_fast_importer_sys_paths()
# Out:
# dict_keys(['/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/extscore/omni.kit.async_engine', '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/extscore/omni.client.lib', '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Full/5.0/exts/3/omni.stats-1.0.1+8131b85d.lx64.r.cp311', '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Full/5.0/exts/3/omni.ujitso.default-1.0.0+8131b85d.lx64.r.cp311', '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Full/5.0/exts/3/omni.gpu_foundation.shadercache.vulkan-1.0.0+8131b85d.lx64.r', '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Full/5.0/exts/3/omni.hsscclient-1.1.2+8131b85d.lx64.r.cp311', '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Full/5.0/exts/3/omni.gpu_foundation-0.0.0+8131b85d.lx64.r.cp311', '/home/sysad
# ...

# %%
import omni.ext.fast_importer

import omni.ext

omni.ext
# Out:
# <module 'omni.ext' from '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/kernel/py/omni/ext/__init__.py'>

# %%
import sys
sys.meta_path.insert
# Out:
# ...
#  _frozen_importlib.BuiltinImporter,
#  _frozen_importlib.FrozenImporter,
#  _frozen_importlib_external.PathFinder,
# ...
