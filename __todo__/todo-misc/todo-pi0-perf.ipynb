# %%
# %env CUDA_VISIBLE_DEVICES=1
# %env XLA_PYTHON_CLIENT_PREALLOCATE=false
# %env TF_GPU_ALLOCATOR=cuda_malloc_async
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=.99
# %env JAX_PLATFORMS=cpu

from robotodo.algos.pi0.nn.pi0 import Pi0
import jax
import flax.nnx

# mesh = jax.sharding.Mesh(jax.devices(), ("x",))
# sharding = jax.sharding.NamedSharding(mesh, jax.sharding.PartitionSpec())

pi0 = Pi0(flax.nnx.Rngs(0))

key = jax.random.key(0)
observation = pi0.observation_spec.random()
action = pi0.action_spec.random()
timestep = jax.numpy.asarray([0])
# Out:
# env: XLA_PYTHON_CLIENT_PREALLOCATE=false
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       2 get_ipython().run_line_magic('env', 'XLA_PYTHON_CLIENT_PREALLOCATE=false')
#       3 # %env TF_GPU_ALLOCATOR=cuda_malloc_async
#       4 # %env XLA_PYTHON_CLIENT_MEM_FRACTION=.99
#       5 # %env JAX_PLATFORMS=cpu
# ----> 7 from robotodo.algos.pi0.nn.pi0 import Pi0
#       8 import jax
#       9 import flax.nnx
#
# File /liujinxin/home/public/lab/robotodo/packages/robotodo/algos/pi0/__init__.py:1
# ----> 1 from .pi0_controller import Pi0Controller
#       4 __all__ = [
#       5     "Pi0Controller",
#       6 ]
#
# File /liujinxin/home/public/lab/robotodo/packages/robotodo/algos/pi0/pi0_controller.py:15
#      12 from tensorspecs import TensorTableSpec, rescale
#      13 from tensorspecs import TensorSpec, BoxSpec, TensorTableSpec, ShapeLike
# ---> 15 from .nn.pi0 import Pi0, Pi0Trainer
#      16 from .nn.paligemma_tokenizer import PaligemmaTokenizer
#      19 def image_resize_transform(
#      20     batch_image: jt.Float[jt.Array, "batch height width channels"],
#      21     image_shape: tuple[int, int, int],
#      22     keep_ratio: bool = True,
#      23 ):
#
# File /liujinxin/home/public/lab/robotodo/packages/robotodo/algos/pi0/nn/pi0.py:89
#      80     sinusoid_input = jnp.einsum(
#      81         "i,j->ij",
#      82         pos,
#      83         1.0 / period * 2 * jnp.pi,
#      84         precision=jax.lax.Precision.HIGHEST,
#      85     )
#      86     return jnp.concatenate([jnp.sin(sinusoid_input), jnp.cos(sinusoid_input)], axis=-1)
# ---> 89 class Pi0(nnx.Module):
#      90     """
#      91     TODO
#      92
#    (...)     97
#      98     """
#     100     class ObservationSpec(TensorTableSpec):
#
# File /liujinxin/home/public/lab/robotodo/packages/robotodo/algos/pi0/nn/pi0.py:418, in Pi0()
#     414     return tokens, input_mask, ar_mask
#     416 # TODO
#     417 # @override
# --> 418 @nnx_frozen_jit
#     419 def sample_actions(
#     420     self,
#     421     rng: jt.PRNGKeyArray,
#     422     batch_observation: SpaceVar[ObservationSpec],
#     423     num_timesteps: int = 1,
#     424     denoising_num_steps: int | jt.Int[jt.Array, ""] = 10,
#     425 ) -> SpaceVar[ActionSpec]:
#     426     """
#     427     Compute actions given a batch of observations.
#     428
#    (...)    446
#     447     """
#     449     # TODO rm
#     450     # observation = _model.preprocess_observation(None, observation, train=False)
#     451     # ###############
#     452
#     453     # note that we use the convention more common in diffusion literature, where t=1 is noise and t=0 is the target
#     454     # distribution. yes, this is the opposite of the pi0 paper, and I'm sorry.
#
# File /liujinxin/home/public/lab/robotodo/packages/robotodo/algos/pi0/nn/utils.py:31, in nnx_frozen_jit(meth, *jit_args, **jit_kwargs)
#      18 """A higher-order function to JIT-compile `nnx.Module` methods, freezing the module's state in the process.
#      19
#      20 Why not `nnx.jit`? For some reason, naively applying `nnx.jit` to `nnx.Module` methods, bound or unbound, uses much
#    (...)     28 after the method call completes.
#      29 """
#      30 if not (inspect.ismethod(meth) and isinstance(meth.__self__, nnx.Module)):
# ---> 31     raise ValueError("module_jit must only be used on bound methods of nnx.Modules.")
#      33 graphdef, state = nnx.split(meth.__self__)
#      35 def fun(state: nnx.State, *args: P.args, **kwargs: P.kwargs) -> R:
#
# ValueError: module_jit must only be used on bound methods of nnx.Modules.

# %%
loss = pi0.compute_loss(
    key,
    observation,
    action,
)
loss.block_until_ready()
# Out:
# Array([[2.7631567]], dtype=float32)

# %%
# %%timeit -n 10

loss = pi0.compute_loss(
    key,
    pi0.observation_spec.random(),
    pi0.action_spec.random(),
)
loss.block_until_ready()
# Out:
# 47.4 ms ± 4.58 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 1

# %%prun
loss = pi0.compute_loss(
    key,
    observation,
    action,
)
loss.block_until_ready()
# Out:
# 43.9 ms ± 632 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit -n 1
pi0._embed_prefix(
    observation,
)
# Out:
# 2.03 s ± 240 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit -n 1

# without nnx.jit
computed_actions = pi0.sample_actions(
    key,
    observation,
)
computed_actions["numeric_states"].block_until_ready()
# Out:
# 6.91 s ± 2.46 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit -n 1

# with nnx.jit 
computed_actions = pi0.sample_actions(
    key,
    observation,
)
computed_actions["numeric_states"].block_until_ready()
# Out:
# 71.6 ms ± 6.76 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
