# %%
from robotodo.engines.isaac._kernel import Kernel
# from robotodo.engines.isaac import Scene, Camera

# %%
# kernel = KernelThread(["--/app/asyncRendering=True"])
kernel = Kernel([
    # "--no-window", 
    # "--/app/window/hideUi=true",
    "--/app/asyncRendering=true",
    # TODO
    # "--enable", "omni.services.streamclient.webrtc",
])
# Out:
# [Warning] [simulation_app] Interactive python shell detected but ISAAC_JUPYTER_KERNEL was not set. Problems with asyncio may occur
# [Warning] [simulation_app] Please use Isaac Sim Python 3 kernel instead of the default Python 3 Kernel
# Loading user config located at: '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Full/5.0/user.config.json'
# 2025-09-08T10:36:20Z s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [0.129s] [ext: omni.kit.async_engine-0.0.3] startup
# [0.667s] [ext: omni.metrics.core-0.0.3] startup
# [0.667s] [ext: omni.client.lib-1.1.0] startup
# [0.693s] [ext: omni.blobkey-1.1.2] startup
# [0.693s] [ext: omni.stats-1.0.1] startup
# [0.695s] [ext: omni.datastore-0.0.0] startup
# [0.717s] [ext: omni.client-1.3.0] startup
# [0.773s] [ext: omni.ujitso.default-1.0.0] startup
# [0.775s] [ext: omni.hsscclient-1.1.2] startup
# ...

# %%
kernel.run_update_loop()
# Out:
# <Future at 0x7efe826cef10 state=pending>
# [18.784s] [ext: isaacsim.ros2.bridge-4.9.3] startup
# 2025-09-08T10:36:39Z [18,794ms] [Warning] [isaacsim.ros2.bridge.impl.extension] ROS_DISTRO env var not found, Please source ROS before enabling this extension
# [18.836s] Using backup internal ROS2 humble distro
# [18.863s] To use the internal libraries included with the extension please set the following environment variables to use with FastDDS (default) or CycloneDDS before starting Isaac Sim:
#
# FastDDS (default):
# export ROS_DISTRO=humble
# export RMW_IMPLEMENTATION=rmw_fastrtps_cpp
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/isaacsim/exts/isaacsim.ros2.bridge/humble/lib
#
# OR
#
# CycloneDDS:
# export ROS_DISTRO=humble
# export RMW_IMPLEMENTATION=rmw_cyclonedds_cpp
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/isaacsim/exts/isaacsim.ros2.bridge/humble/lib
#
#
# ...

# %%
kernel.step_update_loop()
# Out:
# <Future at 0x7f5d588e89d0 state=pending>

# %%
kernel.stop_update_loop().result()

# %%
def todo():
    # kernel._framework.update()
    return
    import omni
    return omni.usd.get_context().get_stage()

# %timeit -n 100 kernel.submit(todo).result()
# Out:
# 14.1 μs ± 1.88 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
def todo():
    import asyncio
    return asyncio.get_running_loop()
kernel.submit(todo).result()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[21], line 4
#       2     import asyncio
#       3     return asyncio.get_running_loop()
# ----> 4 kernel.submit(todo).result()
#
# File ~/lab/robotodo/.conda/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/lab/robotodo/.conda/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# ...

# %%
# kernel.start()
# kernel.wait_until_initialized()
# TODO NOTE required to make a lot of async extensions to work: e.g. omni.usd.get_context().new_stage_async() .get_stage_async()
# kernel.play()

# %%
# %timeit -n 1000 kernel._framework.app.is_running()
# Out:
# 280 ns ± 5.12 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
dir(kernel._app_framework.app)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'delay_app_ready',
#  'ensure_runloop',
#  'get_app_environment',
#  'get_app_filename',
#  'get_app_name',
#  'get_app_version',
#  'get_app_version_short',
#  'get_build_version',
#  'get_extension_manager',
#  'get_kernel_version',
#  'get_kit_version',
#  'get_kit_version_hash',
#  'get_kit_version_short',
#  'get_log_event_stream',
#  'get_message_bus_event_stream',
#  'get_platform_info',
#  'get_post_update_event_stream',
#  'get_pre_update_event_stream',
#  'get_python_scripting',
#  'get_shutdown_event_stream',
#  'get_startup_event_stream',
#  'get_time_since_start_ms',
# ...

# %%
import omni.usd
ctx = omni.usd.get_context()
type(ctx)
# Out:
# omni.usd._usd.UsdContext

# %%
dir(omni.usd.UsdContext)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'attach_stage_async',
#  'attach_stage_with_callback',
#  'can_close_stage',
#  'can_open_stage',
#  'can_save_stage',
#  'close_stage',
#  'close_stage_async',
#  'close_stage_with_callback',
#  'compute_path_world_bounding_box',
#  'compute_path_world_transform',
#  'disable_save_to_recent_files',
#  'enable_save_to_recent_files',
#  'export_as_stage',
#  'export_as_stage_async',
#  'export_as_stage_with_callback',
#  'get_attached_hydra_engine_description',
#  'get_attached_hydra_engine_names',
#  'get_attached_hydra_engine_uids',
#  'get_geometry_instance_path',
#  'get_name',
# ...

# %%
# /app/python/interceptSysStdOutput, /app/python/interceptSysExit

# %%
import carb
s = carb.settings.get_settings()
(s.get_settings_dictionary()).get_dict()['app']['python']
# (s.get_settings_dictionary()).get_dict()["renderer"]
# Out:
# {'sysPaths': ('/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/kernel/py',
#   '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/plugins/bindings-python'),
#  'extraPaths': {},
#  'scriptFolders': ('/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/scripts',
#   '/home/sysadmin/Documents/Kit/apps/Isaac-Sim Full/scripts',
#   '/home/sysadmin/Documents/Kit/shared/scripts'),
#  'disableGCDuringStartup': False,
#  'enableGCProfiling': False,
#  'interceptSysExit': False,
#  'interceptSysStdOutput': False,
#  'logSysStdOutput': False}

# %%
(s.get_settings_dictionary()).get_dict()["log"]
# Out:
# {'level': 'Info',
#  'outputStreamLevel': 'Warning',
#  'debugConsoleLevel': 'Warning',
#  'fileLogLevel': 'Info',
#  'fileMaxCount': 30,
#  'includeTimeStamp': True,
#  'setElapsedTimeUnits': 'milliseconds',
#  'file': '',
#  'enabled': True,
#  'async': False,
#  'fileFlushLevel': 'verbose',
#  'flushStandardStreamOutput': False,
#  'enableStandardStreamOutput': True,
#  'enableDebugConsoleOutput': True,
#  'enableColorOutput': True,
#  'processGroupId': 0,
#  'includeSource': True,
#  'includeChannel': True,
#  'includeFilename': False,
#  'includeLineNumber': False,
#  'includeFunctionName': False,
#  'includeThreadId': False,
#  'includeProcessId': False,
#  'includeTraceId': False,
#  'detail': False,
#  'fullDetail': False,
#  'forceAnsiColor': False,
#  'fileAppend': False,
#  'utcTimestamp': True,
#  'microsecondTimestamp': False,
#  'menuWarningSilence': False}
# ...

# %%
(s.get_settings_dictionary()).get_dict()["log"]
# Out:
# {'level': 'Info',
#  'outputStreamLevel': 'Warning',
#  'debugConsoleLevel': 'Warning',
#  'fileLogLevel': 'Info',
#  'file': '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/logs/Kit/Isaac-Sim Full/5.0/kit_20250907_024551.log',
#  'fileMaxCount': 30,
#  'includeTimeStamp': True,
#  'setElapsedTimeUnits': 'milliseconds',
#  'enabled': False,
#  'async': False,
#  'fileFlushLevel': 'verbose',
#  'flushStandardStreamOutput': False,
#  'enableStandardStreamOutput': True,
#  'enableDebugConsoleOutput': True,
#  'enableColorOutput': True,
#  'processGroupId': 0,
#  'includeSource': True,
#  'includeChannel': True,
#  'includeFilename': False,
#  'includeLineNumber': False,
#  'includeFunctionName': False,
#  'includeThreadId': False,
#  'includeProcessId': False,
#  'includeTraceId': False,
#  'detail': False,
#  'fullDetail': False,
#  'forceAnsiColor': False,
#  'fileAppend': False,
#  'utcTimestamp': True,
#  'microsecondTimestamp': False,
# ...

# %%
import gc
gc.get_stats()
# Out:
# [{'collections': 445, 'collected': 27311, 'uncollectable': 0},
#  {'collections': 40, 'collected': 5582, 'uncollectable': 0},
#  {'collections': 4, 'collected': 39494, 'uncollectable': 0}]

# %%
s.get("/app/python/logSysStdOutput")
s.get("/app/enableStdoutOutput")
# Out:
# False

# %%
# kernel = KernelThread(["--/app/asyncRendering=True"])
kernel_0 = Kernel([
    "--no-window", 
    # "--/app/window/hideUi=true",
    "--/app/asyncRendering=true",
    # TODO
    # "--enable", "omni.services.streamclient.webrtc",
])
# Out:
# [0.000s] [ext: isaacsim.exp.full-5.0.0] shutdown
# [0.000s] [ext: isaacsim.examples.interactive-4.6.10] shutdown
# [0.201s] [ext: isaacsim.exp.base-5.0.0] shutdown
# [0.201s] [ext: omni.anim.shared.core-107.0.1] shutdown
# [0.399s] [ext: omni.graph.bundle.action-2.30.0] shutdown
# [0.596s] [ext: omni.isaac.cortex.sample_behaviors-2.0.5] shutdown
# [0.791s] [ext: isaacsim.cortex.behaviors-2.0.12] shutdown
# [0.982s] [ext: omni.isaac.cortex-1.0.5] shutdown
# [1.168s] [ext: isaacsim.cortex.framework-1.0.12] shutdown
# [1.352s] [ext: omni.isaac.franka-1.0.7] shutdown
# [1.541s] [ext: omni.isaac.universal_robots-1.0.6] shutdown
# [1.726s] [ext: isaacsim.robot.manipulators.examples-1.0.17] shutdown
# [1.908s] [ext: isaacsim.robot.manipulators.ui-2.1.22] shutdown
# [2.096s] [ext: omni.isaac.manipulators-3.0.7] shutdown
# [2.276s] [ext: isaacsim.robot.manipulators-3.3.5] shutdown
# [2.467s] [ext: omni.isaac.quadruped-3.0.7] shutdown
# ...

# %%
def todo():
    stage = kernel._omni.usd.get_context().get_stage()
    return stage
    # from pxr import Usd, UsdPhysics

    # scene = UsdPhysics.Scene.Define(stage, "/World/physicsScene")
    # # scene.CreateGravityMagnitudeAttr(9.81)
    # return scene

kernel.submit(todo).result()

# %%
def todo():
    return kernel._should_run_update_loop
# %timeit -n 1000 todo()
# Out:
# 85.4 ns ± 1.5 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit -n 1000 kernel._should_run_update_loop
# Out:
# 26.9 ns ± 2.82 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
stage = kernel._omni.usd.get_context().get_stage()

# %%
from pxr import Usd, UsdPhysics
UsdPhysics.Scene.Define
# Out:
# <function Scene.Define>

# %%
from pxr import Usd, UsdPhysics

scene = UsdPhysics.Scene.Define(stage, "/World/physicsScene")
# scene.CreateGravityMagnitudeAttr(9.81)
scene

# %%
{p: p.GetTypeName() for p in stage.Traverse()}
# Out:
# {Usd.Prim(</World>): 'Xform',
#  Usd.Prim(</Environment>): 'Xform',
#  Usd.Prim(</Environment/defaultLight>): 'DistantLight',
#  Usd.Prim(</Render>): '',
#  Usd.Prim(</Render/OmniverseKit>): '',
#  Usd.Prim(</Render/OmniverseKit/HydraTextures>): '',
#  Usd.Prim(</Render/OmniverseKit/HydraTextures/omni_kit_widget_viewport_ViewportTexture_0>): 'RenderProduct',
#  Usd.Prim(</Render/OmniverseGlobalRenderSettings>): 'RenderSettings',
#  Usd.Prim(</Render/Vars>): '',
#  Usd.Prim(</Render/Vars/LdrColor>): 'RenderVar',
#  Usd.Prim(</OmniverseKit_Persp>): 'Camera',
#  Usd.Prim(</OmniverseKit_Front>): 'Camera',
#  Usd.Prim(</OmniverseKit_Top>): 'Camera',
#  Usd.Prim(</OmniverseKit_Right>): 'Camera'}

# %%
kernel._omni.timeline.get_timeline_interface().stop()

# %%
kernel.physics_get_view()
# Out:
# 2025-09-05T16:01:24Z [108,743ms] [Error] [omni.physx.tensors.plugin] Failed to create simulation view: no active physics scene found
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/lab/robotodo/packages/robotodo/engines/isaac/_kernel.py:281, in KernelThread.__physics_view(self)
#     280 try:
# --> 281     res = self._omni.physics.tensors.create_simulation_view("torch")
#     282 except Exception as error:
#     283     # TODO
#
# File ~/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Full/5.0/exts/3/omni.physics.tensors-107.3.18+107.3.1.lx64.r.cp311.u353/omni/physics/tensors/impl/api.py:29, in create_simulation_view(frontend_name, stage_id)
#      28 if backend is None:
# ---> 29     raise Exception("Failed to create simulation view backend")
#      31 device_ordinal = backend.device_ordinal
#
# ...

# %%
kernel.stop_update_loop()
# Out:
# <Future at 0x7f36021e2710 state=pending>
