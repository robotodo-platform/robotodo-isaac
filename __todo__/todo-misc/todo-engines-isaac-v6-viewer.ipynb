# %%
# %load_ext autoreload
# %autoreload complete
# %aimport ...
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from robotodo.engines.isaac._kernel import Kernel

# kernel = Kernel(["--empty", "--enable", "omni.kit.uiapp", "--list-exts"], kit_path=None)
# kernel = Kernel(["--empty", "--enable", "isaacsim.exp.base"], kit_path=None)
# kernel = Kernel(["--enable", "isaacsim.exp.full"])
kernel = Kernel(kit_path="isaacsim.exp.full.kit")
kernel.start_app_loop_soon()
# Out:
# [Warning] [simulation_app] Interactive python shell detected but ISAAC_JUPYTER_KERNEL was not set. Problems with asyncio may occur
# [Warning] [simulation_app] Please use Isaac Sim Python 3 kernel instead of the default Python 3 Kernel
# Loading user config located at: '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Full/5.0/user.config.json'
# 2025-09-23T07:17:15Z s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [0.096s] [ext: omni.kit.async_engine-0.0.3] startup
# [0.675s] [ext: omni.metrics.core-0.0.3] startup
# [0.676s] [ext: omni.client.lib-1.1.0] startup
# [0.702s] [ext: omni.blobkey-1.1.2] startup
# [0.702s] [ext: omni.stats-1.0.1] startup
# [0.704s] [ext: omni.datastore-0.0.0] startup
# [0.736s] [ext: omni.client-1.3.0] startup
# [0.793s] [ext: omni.ujitso.default-1.0.0] startup
# [0.795s] [ext: omni.hsscclient-1.1.2] startup
# ...

# %%
# from isaacsim.replicator.grasping.ui import grasping_ui_utils


# grasping_ui_utils.clear_debug_draw()
# # TODO customize: Axis colors: X=Red, Y=Green, Z=Blue
# grasping_ui_utils.draw_grasp_samples_as_axes

# %%
dir(kernel.isaacsim.util.debug_draw)
# Out:
# ['Extension',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_debug_draw',
#  'impl',
#  'omni',
#  'tests']

# %%
import random
from isaacsim.util.debug_draw import _debug_draw
draw = _debug_draw.acquire_debug_draw_interface()
N = 10000
point_list_1 = [
    (random.uniform(0, 1), random.uniform(0, 1), random.uniform(0, 1)) for _ in range(N)
]
point_list_2 = [
    (random.uniform(0, 1), random.uniform(0, 1), random.uniform(0, 1)) for _ in range(N)
]
colors = [(random.uniform(0, 1), random.uniform(0, 1), random.uniform(0, 1), 1) for _ in range(N)]
sizes = [random.randint(1, 25) for _ in range(N)]
draw.draw_lines(point_list_1, point_list_2, colors, sizes)

# %%
draw.clear_lines
# Out:
# <bound method PyCapsule.clear_lines of <isaacsim.util.debug_draw._debug_draw.DebugDraw object at 0x7f5cf513f130>>

# %%
_debug_draw.release_debug_draw_interface(draw)

# %%
_debug_draw.acquire_debug_draw_interface?
# Out:
# Docstring: acquire_debug_draw_interface(plugin_name: str = None, library_path: str = None) -> isaacsim.util.debug_draw._debug_draw.DebugDraw
# Type:      builtin_function_or_method

# %%
from robotodo.utils.pose import Pose


Pose(p=[1, 2, 3], q=[.3, .4, .1, 1]) * Pose(p=[1, 0, 0])
# Out:
# Pose(p=array([1.73015873, 2.34920635, 2.41269841]), q=array([0.26726124, 0.35634832, 0.08908708, 0.89087081]))

# %%
from robotodo.engines.isaac.scene import Scene
scene = Scene(_kernel=kernel)

# %%
import sys
import importlib
importlib.reload(sys.modules["robotodo.engines.isaac.viewer"])
importlib.reload(sys.modules["robotodo.engines.isaac"])
# Out:
# <module 'robotodo.engines.isaac' from '/home/sysadmin/lab/robotodo/packages/robotodo/engines/isaac/__init__.py'>

# %%
from robotodo.engines.isaac.viewer import Viewer

viewer = Viewer(scene=scene)

# %%
import numpy

viewer.clear_drawings()

viewer.draw_pose(
    Pose(p=[0, 0, 0]) #.rotated([0, 0, 0])
)
# viewer.draw_pose(
#     Pose(p=[0, 0, 0]).rotated([0, 0, numpy.deg2rad(360)])
# )

# %%
Pose(p=[1, 1, 1]).rotated([0, 0, numpy.deg2rad(180)]).q
# Out:
# array([0.000000e+00, 0.000000e+00, 1.000000e+00, 6.123234e-17])

# %%
(Pose(p=[0, 0, 0]) * Pose(p=[1, 0, 0]) * Pose(p=[2.4, 2., 231.1])).p
# Out:
# array([  3.4,   2. , 231.1])
