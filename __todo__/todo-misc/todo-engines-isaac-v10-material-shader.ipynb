# %%
# %env CUDA_LAUNCH_BLOCKING=1
# %load_ext autoreload
# %autoreload complete
# %aimport ...

import sys
import importlib
import warnings

importlib.invalidate_caches()

for mod_name in list(sys.modules):
    if not (str.startswith(mod_name, "robotodo") or str.startswith(mod_name, "tensorspecs")):
        continue
    try:
        importlib.reload(sys.modules[mod_name])
    except Exception as error:
        warnings.warn(f"{error}")


from robotodo.engines.isaac._kernel import configure_default_kernel
configure_default_kernel(
    extra_argv=[
        "--/log/file=/tmp/todo-isaacsim.log",
        "--/app/settings/loadUserConfig=false",
        # "--/log/enableStandardStreamOutput=true",
        "--/app/enableStdoutOutput=true",
        # "--no-window",
        # TODO
        # "--/app/content/emptyStageOnStart=false",
        # "--/app/asyncRendering=true",
        # "--enable", "isaacsim.exp.full",
        # "--/app/vulkan=",
    ], 
    kit_path="isaacsim.exp.full.kit",
)
# Out:
# env: CUDA_LAUNCH_BLOCKING=1

# %%
# TODO 
from robotodo.engines.isaac.builders import load_usd_scene

# TODO set up axis
scene = await load_usd_scene(
    # "https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/5.0/Isaac/Environments/Simple_Room/simple_room.usd",
    "https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/5.0/Isaac/Environments/Grid/default_environment.usd",
    # "https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/5.0/Isaac/Environments/Grid/gridroom_black.usd",
)
# Out:
# [Warning] [simulation_app] Interactive python shell detected but ISAAC_JUPYTER_KERNEL was not set. Problems with asyncio may occur
# [Warning] [simulation_app] Please use Isaac Sim Python 3 kernel instead of the default Python 3 Kernel
# [0.109s] [ext: omni.kit.async_engine-0.0.3] startup
# [0.377s] [ext: omni.metrics.core-0.0.3] startup
# [0.378s] [ext: omni.client.lib-1.1.0] startup
# [0.403s] [ext: omni.blobkey-1.1.2] startup
# [0.404s] [ext: omni.stats-1.0.1] startup
# [0.405s] [ext: omni.datastore-0.0.0] startup
# [0.413s] [ext: omni.client-1.3.0] startup
# [0.469s] [ext: omni.ujitso.default-1.0.0] startup
# [0.471s] [ext: omni.hsscclient-1.1.2] startup
# [0.476s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.479s] [ext: omni.assets.plugins-0.0.0] startup
# [0.480s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.487s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.494s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 535.247.01    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 3060          | Yes: 0 |     | 12288   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2504      | 3157457f.. |
# |     |                                  |        |     |            | 1         |            |
# |=============================================================================================|
# | OS: 12 (bookworm) debian, Version: 12.00.0, Kernel: 6.1.0-35-amd64
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101007 (1.21.1.7)
# | Processor: 12th Gen Intel(R) Core(TM) i5-12400F
# | Cores: 6 | Logical Cores: 12
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 64139 | Free Memory: 29146
# | Total Page/Swap (MB): 16383 | Free Page/Swap: 15952
# |---------------------------------------------------------------------------------------------|
# [1.165s] [ext: omni.kit.pipapi-0.0.0] startup
# [1.167s] [ext: omni.materialx.libs-1.0.7] startup
# [1.178s] [ext: omni.kit.pip_archive-0.0.0] startup
# [1.179s] [ext: omni.usd.config-1.0.6] startup
# [1.183s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [1.183s] [ext: omni.usd.libs-1.0.1] startup
# [1.292s] [ext: omni.mdl-56.0.3] startup
# [1.334s] [ext: omni.iray.libs-0.0.0] startup
# [1.340s] [ext: omni.mdl.neuraylib-0.2.12] startup
# [1.344s] [ext: omni.kit.usd.mdl-1.1.4] startup
# [1.485s] [ext: omni.kit.telemetry-0.5.2] startup
# [1.519s] [ext: omni.pip.compute-1.6.2] startup
# [1.521s] [ext: omni.kit.loop-isaac-1.3.7] startup
# [1.523s] [ext: omni.kit.test-2.0.1] startup
# [1.562s] [ext: omni.appwindow-1.1.10] startup
# [2.149s] [ext: omni.kit.renderer.core-1.1.0] startup
# [5.209s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [5.217s] [ext: omni.kit.renderer.imgui-2.0.5] startup
# [5.695s] [ext: omni.ui-2.26.18] startup
# [5.703s] [ext: omni.kit.mainwindow-1.0.3] startup
# [5.704s] [ext: carb.audio-0.1.0] startup
# [5.707s] [ext: omni.uiaudio-1.0.0] startup
# [5.708s] [ext: omni.kit.uiapp-0.0.0] startup
# [5.708s] [ext: omni.usd.schema.metrics.assembler-107.3.1] startup
# [5.709s] [ext: omni.usd.schema.audio-0.0.0] startup
# [5.712s] [ext: omni.usd.schema.isaac-3.0.5] startup
# [5.712s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [5.715s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [5.717s] [ext: omni.usd.schema.anim-0.0.0] startup
# [5.735s] [ext: usdrt.scenegraph-7.6.1] startup
# [5.850s] [ext: omni.activity.core-1.0.3] startup
# [5.852s] [ext: omni.kit.actions.core-1.0.0] startup
# [5.854s] [ext: omni.usd_resolver-1.0.0] startup
# [5.858s] [ext: omni.kit.commands-1.4.10] startup
# [5.862s] [ext: omni.usd.core-1.5.3] startup
# [5.865s] [ext: omni.resourcemonitor-107.0.1] startup
# [5.867s] [ext: omni.kit.audiodeviceenum-1.0.2] startup
# [5.868s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [5.876s] [ext: omni.kit.usd_undo-0.1.8] startup
# [5.877s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [5.882s] [ext: omni.graph.exec-0.9.6] startup
# [5.882s] [ext: omni.timeline-1.0.14] startup
# [5.884s] [ext: omni.kit.widget.nucleus_connector-2.0.1] startup
# [5.885s] [ext: omni.kit.exec.core-0.13.4] startup
# [5.989s] [ext: omni.hydra.scene_delegate-0.3.4] startup
# [5.994s] [ext: omni.usd-1.13.10] startup
# [6.032s] [ext: omni.kit.asset_converter-5.0.12] startup
# [6.042s] [ext: isaacsim.robot.schema-3.5.1] startup
# [6.049s] [ext: omni.anim.navigation.schema-107.3.0] startup
# [6.053s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [6.058s] [ext: omni.inspect-1.0.2] startup
# [6.059s] [ext: omni.kit.notification_manager-1.0.10] startup
# [6.060s] [ext: omni.graph.core-2.184.3] startup
# [6.063s] [ext: isaacsim.core.deprecation_manager-0.2.7] startup
# [6.064s] [ext: omni.usd.schema.scene.visualization-2.0.2] startup
# [6.065s] [ext: omni.pip.cloud-1.3.6] startup
# [6.067s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [6.071s] [ext: omni.anim.graph.schema-107.3.0] startup
# [6.077s] [ext: omni.usd.schema.render_settings.rtx-0.0.0] startup
# [6.077s] [ext: omni.usd.schema.physx-107.3.18] startup
# [6.107s] [ext: omni.usd.schema.omni_lens_distortion-0.0.0] startup
# [6.108s] [ext: omni.usd.schema.omni_sensors-0.0.0] startup
# [6.109s] [ext: omni.usd.schema.flow-107.1.1] startup
# [6.109s] [ext: omni.index.libs-380600.5717.0] startup
# [6.109s] [ext: omni.index-1.0.1] startup
# [6.110s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [6.111s] [ext: omni.kit.helper.file_utils-0.1.9] startup
# [6.114s] [ext: omni.kit.widget.nucleus_info-2.0.2] startup
# [6.115s] [ext: omni.kit.menu.core-1.1.2] startup
# [6.115s] [ext: omni.kit.widget.filebrowser-2.12.2] startup
# [6.119s] [ext: omni.kit.search_core-1.0.8] startup
# [6.120s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [6.123s] [ext: omni.kit.widget.path_field-2.0.11] startup
# [6.123s] [ext: omni.kit.widget.context_menu-1.2.5] startup
# [6.124s] [ext: omni.kit.widget.search_delegate-1.0.7] startup
# [6.125s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [6.126s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [6.126s] [ext: omni.ui.scene-1.11.4] startup
# [6.131s] [ext: omni.kit.widget.versioning-1.4.10] startup
# [6.133s] [ext: omni.kit.clipboard-1.0.5] startup
# [6.134s] [ext: omni.kit.collaboration.telemetry-1.1.0] startup
# [6.134s] [ext: omni.kit.window.filepicker-2.13.3] startup
# [6.143s] [ext: omni.kit.collaboration.channel_manager-1.0.14] startup
# [6.143s] [ext: omni.volume-0.5.2] startup
# [6.146s] [ext: omni.ujitso.client-0.0.0] startup
# [6.146s] [ext: omni.kit.usd.layers-2.2.10] startup
# [6.154s] [ext: omni.hydra.rtx-1.0.0] startup
# [6.185s] [ext: omni.kit.window.file_importer-1.1.18] startup
# [6.188s] [ext: omni.kit.menu.utils-2.0.3] startup
# [6.195s] [ext: omni.kit.context_menu-1.8.6] startup
# [6.196s] [ext: omni.kit.raycast.query-1.1.0] startup
# [6.202s] [ext: omni.kit.material.library-2.0.7] startup
# [6.206s] [ext: omni.hydra.engine.stats-1.0.3] startup
# [6.209s] [ext: omni.kit.viewport.scene_camera_model-1.0.6] startup
# [6.213s] [ext: omni.kit.hydra_texture-1.4.5] startup
# [6.217s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [6.218s] [ext: omni.kit.window.drop_support-1.0.5] startup
# [6.218s] [ext: omni.kit.widget.viewport-107.1.3] startup
# [6.221s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [6.222s] [ext: omni.kit.viewport.legacy_gizmos-1.0.18] startup
# [6.224s] [ext: omni.kit.widget.settings-1.2.3] startup
# [6.226s] [ext: omni.kit.viewport.window-107.0.12] startup
# [6.240s] [ext: omni.kit.window.preferences-1.8.0] startup
# [6.248s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [6.250s] [ext: omni.kit.widget.filter-1.1.4] startup
# [6.250s] [ext: omni.kit.viewport.utility-1.1.2] startup
# [6.251s] [ext: omni.kit.manipulator.transform-107.0.0] startup
# [6.255s] [ext: omni.graph.tools-1.79.2] startup
# [6.275s] [ext: omni.kit.widget.text_editor-1.1.1] startup
# [6.276s] [ext: omni.graph-1.141.2] startup
# [6.316s] [ext: omni.kit.window.extensions-1.4.26] startup
# [6.321s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [6.322s] [ext: omni.kit.window.file_exporter-1.0.33] startup
# [6.323s] [ext: omni.kit.hotkeys.core-1.3.10] startup
# [6.325s] [ext: omni.kit.widget.live_session_management.ui-1.0.3] startup
# [6.328s] [ext: omni.kit.collaboration.presence_layer-1.1.2] startup
# [6.330s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [6.331s] [ext: omni.kit.widget.stage-3.1.4] startup
# [6.342s] [ext: omni.kit.widget.live_session_management-1.2.23] startup
# [6.345s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [6.346s] [ext: omni.kit.property.adapter.core-1.0.2] startup
# [6.347s] [ext: omni.kit.widget.highlight_label-1.0.3] startup
# [6.349s] [ext: omni.kit.window.file-2.0.5] startup
# [6.351s] [ext: omni.kit.property.adapter.usd-1.0.2] startup
# [6.353s] [ext: omni.kit.window.property-1.12.1] startup
# [6.355s] [ext: omni.kit.window.content_browser-3.1.1] startup
# [6.366s] [ext: omni.kit.property.adapter.fabric-1.0.3] startup
# [6.367s] [ext: omni.kit.widget.toolbar-2.0.1] startup
# [6.373s] [ext: omni.kit.property.usd-4.5.11] startup
# [6.383s] [ext: omni.kit.manipulator.tool.snap-1.5.13] startup
# [6.389s] [ext: omni.kit.manipulator.selector-1.1.3] startup
# [6.391s] [ext: isaacsim.core.version-2.0.6] startup
# [6.392s] [ext: omni.ui_query-1.1.8] startup
# [6.393s] [ext: isaacsim.storage.native-1.2.8] startup
# [6.395s] [ext: omni.graph.ui-1.101.7] startup
# [6.419s] [ext: omni.kit.viewport.manipulator.transform-107.0.4] startup
# [6.424s] [ext: omni.kit.manipulator.viewport-107.0.1] startup
# [6.426s] [ext: omni.graph.scriptnode-1.50.0] startup
# [6.427s] [ext: omni.kvdb-107.3.18] startup
# [6.431s] [ext: omni.kit.manipulator.prim.core-107.0.8] startup
# [6.449s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [6.452s] [ext: omni.physx.foundation-107.3.18] startup
# [6.455s] [ext: omni.localcache-107.3.18] startup
# [6.456s] [ext: omni.convexdecomposition-107.3.18] startup
# [6.459s] [ext: omni.kit.manipulator.prim.usd-107.0.3] startup
# [6.460s] [ext: omni.fabric.commands-1.1.6] startup
# [6.463s] [ext: omni.usdphysics-107.3.18] startup
# [6.465s] [ext: omni.kit.manipulator.prim.fabric-107.0.4] startup
# [6.467s] [ext: omni.physx.cooking-107.3.18] startup
# [6.470s] [ext: omni.physics-107.3.18] startup
# [6.473s] [ext: omni.kit.window.cursor-1.1.4] startup
# [6.474s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [6.474s] [ext: omni.debugdraw-0.1.4] startup
# [6.479s] [ext: omni.physx-107.3.18] startup
# [6.489s] [ext: omni.physics.stageupdate-107.3.18] startup
# [6.492s] [ext: omni.kit.viewport.menubar.core-107.1.5] startup
# [6.505s] [ext: omni.kit.viewport.actions-107.0.2] startup
# [6.509s] [ext: omni.kit.widget.layers-1.8.6] startup
# [6.519s] [ext: omni.kit.viewport.menubar.display-107.0.3] startup
# [6.521s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [6.526s] [ext: omni.kit.widget.graph-2.0.0] startup
# [6.611s] [ext: omni.usdphysics.ui-107.3.18] startup
# [6.635s] [ext: omni.physx.commands-107.3.18] startup
# [6.641s] [ext: omni.physics.tensors-107.3.18] startup
# [6.646s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [6.647s] [ext: omni.usd.metrics.assembler-107.3.1] startup
# [6.651s] [ext: omni.physx.ui-107.3.18] startup
# [6.675s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [6.678s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [6.680s] [ext: omni.warp.core-1.8.1] startup
# [6.682s] [ext: omni.usd.metrics.assembler.physics-107.3.18] startup
# [6.684s] [ext: omni.physics.physx-107.3.18] startup
# [6.686s] [ext: omni.kit.numpy.common-0.1.2] startup
# [6.688s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [6.689s] [ext: omni.isaac.dynamic_control-2.0.7] startup
# [6.695s] [ext: omni.kit.window.material_graph-1.8.23] startup
# [6.723s] [ext: omni.graph.image.core-0.6.1] startup
# [6.724s] [ext: isaacsim.core.utils-3.4.5] startup
# [6.727s] [ext: omni.kit.stage_templates-2.0.0] startup
# [6.731s] [ext: omni.graph.action_core-1.1.7] startup
# [6.733s] [ext: omni.kit.widget.stage_icons-1.0.8] startup
# [6.734s] [ext: omni.physx.tensors-107.3.18] startup
# [6.799s] [ext: isaacsim.test.docstring-1.1.0] startup
# [6.803s] [ext: isaacsim.core.simulation_manager-1.3.2] startup
# [6.943s] [ext: isaacsim.core.experimental.utils-0.2.0] startup
# [6.946s] [ext: omni.graph.action_nodes_core-1.2.0] startup
# [6.949s] [ext: omni.kit.window.stage-2.6.1] startup
# [6.953s] [ext: isaacsim.core.experimental.prims-0.6.2] startup
# [6.983s] [ext: omni.graph.action_nodes-1.51.0] startup
# [6.988s] [ext: omni.kit.menu.stage-1.2.7] startup
# [6.990s] [ext: omni.graph.visualization.nodes-2.1.3] startup
# [7.017s] [ext: omni.graph.action-1.130.0] startup
# [7.017s] [ext: omni.kit.widget.zoombar-1.0.7] startup
# [7.021s] [ext: omni.kit.usd.collect-2.4.5] startup
# [7.025s] [ext: omni.kit.browser.core-2.3.16] startup
# [7.034s] [ext: omni.kit.tool.collect-2.2.18] startup
# [7.037s] [ext: omni.kit.browser.folder.core-1.10.10] startup
# [7.042s] [ext: omni.kit.usdz_export-1.0.9] startup
# [7.045s] [ext: omni.kit.ui_test-1.3.6] startup
# [7.048s] [ext: omni.kit.tool.asset_importer-4.3.2] startup
# [7.055s] [ext: isaacsim.gui.components-1.1.9] startup
# [7.059s] [ext: isaacsim.examples.browser-0.1.12] startup
# [7.065s] [ext: isaacsim.asset.importer.urdf-2.4.19] startup
# [7.136s] [ext: isaacsim.core.prims-0.5.1] startup
# [7.162s] [ext: omni.graph.image.nodes-1.3.1] startup
# [7.165s] [ext: isaacsim.core.experimental.materials-0.3.0] startup
# [7.168s] [ext: omni.graph.nodes_core-1.1.0] startup
# [7.176s] [ext: isaacsim.core.api-4.6.10] startup
# [7.186s] [ext: omni.kit.selection-0.1.6] startup
# [7.189s] [ext: omni.graph.nodes-1.171.0] startup
# [7.196s] [ext: omni.kit.widget.imageview-1.0.4] startup
# [7.198s] [ext: isaacsim.robot.surface_gripper-3.2.6] startup
# [7.201s] [ext: isaacsim.gui.menu-2.3.17] startup
# [7.866s] [ext: omni.graph.ui_nodes-1.50.8] startup
# [7.872s] [ext: omni.videoencoding-0.1.2] startup
# [7.876s] [ext: omni.syntheticdata-0.6.13] startup
# [7.893s] [ext: isaacsim.robot.surface_gripper.ui-3.0.2] startup
# [7.896s] [ext: omni.warp-1.8.1] startup
# [7.906s] [ext: omni.kit.window.quicksearch-2.4.4] startup
# [7.923s] [ext: omni.kit.graph.widget.variables-2.1.0] startup
# [7.927s] [ext: omni.kit.graph.delegate.modern-1.10.8] startup
# [7.932s] [ext: omni.replicator.core-1.12.17] startup
# Warp 1.8.1 initialized:
#    CUDA Toolkit 12.8, Driver 12.2
#    Devices:
#      "cpu"      : "CPU"
#      "cuda:0"   : "NVIDIA GeForce RTX 3060" (12 GiB, sm_86, mempool enabled)
#    Kernel cache:
#      /home/sysadmin/.cache/warp/1.8.1
# [8.182s] [ext: omni.graph.window.core-2.0.0] startup
# [8.209s] [ext: isaacsim.core.nodes-3.2.16] startup
# [8.398s] [ext: omni.graph.window.generic-1.50.2] startup
# [8.421s] [ext: isaacsim.sensors.camera-1.3.1] startup
# [8.442s] [ext: isaacsim.core.throttling-2.1.10] startup
# [8.452s] [ext: isaacsim.sensors.camera.ui-0.2.0] startup
# [8.463s] [ext: isaacsim.sensors.physics-0.3.27] startup
# [8.485s] [ext: omni.anim.navigation.core-107.3.0] startup
# [8.507s] [ext: isaacsim.robot.policy.examples-4.1.11] startup
# [8.516s] [ext: omni.anim.navigation.meshtools-107.3.0] startup
# [8.532s] [ext: omni.isaac.quadruped-3.0.7] startup
# [8.540s] [ext: isaacsim.robot_motion.lula-4.0.8] startup
# [8.563s] [ext: isaacsim.asset.browser-1.3.19] startup
# [8.589s] [ext: isaacsim.robot.manipulators-3.3.5] startup
# [8.602s] [ext: isaacsim.robot_motion.motion_generation-8.0.25] startup
# [8.646s] [ext: omni.isaac.asset_browser-1.0.6] startup
# [8.649s] [ext: isaacsim.core.cloner-1.4.9] startup
# [8.660s] [ext: isaacsim.robot.manipulators.examples-1.0.17] startup
# [8.663s] [ext: omni.isaac.assets_check-0.3.13] startup
# [8.667s] [ext: omni.isaac.cloner-1.0.7] startup
# [8.671s] [ext: isaacsim.cortex.framework-1.0.12] startup
# [8.682s] [ext: omni.isaac.core-4.0.7] startup
# [8.689s] [ext: isaacsim.core.experimental.objects-0.2.4] startup
# [8.715s] [ext: isaacsim.cortex.behaviors-2.0.12] startup
# [8.723s] [ext: omni.isaac.cortex-1.0.5] startup
# [8.727s] [ext: isaacsim.simulation_app-2.9.2] startup
# [8.730s] [ext: omni.isaac.cortex.sample_behaviors-2.0.5] startup
# [8.736s] [ext: omni.kit.viewport.menubar.render-107.0.9] startup
# [8.767s] [ext: omni.isaac.kit-2.0.6] startup
# [8.771s] [ext: omni.sensors.nv.common-2.7.0-coreapi] startup
# [8.806s] [ext: omni.isaac.franka-1.0.7] startup
# [8.836s] [ext: omni.isaac.lula-4.0.6] startup
# [8.868s] [ext: isaacsim.robot_motion.lula_test_widget-1.0.12] startup
# [8.882s] [ext: omni.sensors.nv.materials-1.6.0-coreapi] startup
# [8.891s] [ext: omni.sensors.nv.wpm-2.5.0-coreapi] startup
# [8.893s] [ext: omni.sensors.net-0.4.0-coreapi] startup
# [8.897s] [ext: omni.isaac.lula_test_widget-1.0.6] startup
# [8.904s] [ext: isaacsim.util.debug_draw-3.1.0] startup
# [8.924s] [ext: omni.sensors.nv.radar-2.8.0-coreapi] startup
# [8.962s] [ext: omni.sensors.nv.lidar-2.7.0-coreapi] startup
# [8.970s] [ext: omni.sensors.nv.ids-1.5.0-coreapi] startup
# [8.984s] [ext: isaacsim.gui.sensors.icon-2.0.3] startup
# [9.013s] [ext: isaacsim.sensors.physx-2.2.27] startup
# [9.037s] [ext: isaacsim.sensors.rtx-15.5.0] startup
# [9.099s] [ext: isaacsim.gui.content_browser-0.1.9] startup
# [9.132s] [ext: omni.isaac.range_sensor-4.0.6] startup
# [9.144s] [ext: omni.isaac.sensor-13.0.7] startup
# [9.158s] [ext: isaacsim.robot.wheeled_robots-4.0.23] startup
# Warp DeprecationWarning: The `warp.sim` module is deprecated and will be removed in v1.10. Please transition to using the forthcoming Newton library instead.
# [9.435s] [ext: omni.isaac.surface_gripper-2.0.6] startup
# [9.444s] [ext: omni.isaac.universal_robots-1.0.6] startup
# [9.454s] [ext: omni.isaac.utils-2.0.6] startup
# [9.457s] [ext: omni.isaac.version-2.0.7] startup
# [9.462s] [ext: omni.isaac.wheeled_robots-3.0.7] startup
# [9.474s] [ext: omni.kit.menu.create-2.0.1] startup
# [9.481s] [ext: omni.kit.property.audio-1.0.16] startup
# [9.487s] [ext: omni.kit.property.camera-1.0.10] startup
# [9.491s] [ext: omni.kit.property.geometry-2.0.4] startup
# [9.511s] [ext: omni.hydra.scene_api-0.1.2] startup
# [9.527s] [ext: omni.kit.property.light-1.0.12] startup
# [9.544s] [ext: isaacsim.app.about-2.0.11] startup
# [9.547s] [ext: omni.kit.property.material-1.11.9] startup
# [9.558s] [ext: omni.kit.property.render-1.2.1] startup
# [9.569s] [ext: omni.kit.property.transform-1.5.12] startup
# [9.572s] [ext: isaacsim.gui.property-1.1.3] startup
# [9.576s] [ext: omni.isaac.window.about-2.0.7] startup
# [9.578s] [ext: omni.kit.manipulator.camera-106.0.4] startup
# [9.582s] [ext: omni.isaac.core_nodes-2.0.6] startup
# [9.585s] [ext: omni.kit.property.bundle-1.4.1] startup
# [9.588s] [ext: omni.kit.property.isaac-1.0.6] startup
# [9.589s] [ext: omni.kit.scripting-107.3.1] startup
# [9.595s] [ext: omni.isaac.manipulators-3.0.7] startup
# [9.597s] [ext: omni.kit.viewport.menubar.camera-107.0.3] startup
# [9.608s] [ext: omni.kit.viewport.menubar.lighting-107.3.1] startup
# [9.611s] [ext: isaacsim.replicator.writers-1.0.15] startup
# [9.626s] [ext: omni.isaac.menu-1.0.6] startup
# [9.629s] [ext: isaacsim.replicator.behavior-1.1.14] startup
# [9.631s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [9.649s] [ext: omni.kit.window.console-1.1.4] startup
# [9.654s] [ext: isaacsim.replicator.domain_randomization-1.0.16] startup
# [9.656s] [ext: isaacsim.replicator.examples-1.1.31] startup
# [9.660s] [ext: omni.ocio-0.1.1] startup
# [9.665s] [ext: omni.rtx.window.settings-0.6.19] startup
# [9.684s] [ext: omni.kit.window.status_bar-0.1.8] startup
# [9.693s] [ext: omni.kit.window.toolbar-2.0.0] startup
# [9.696s] [ext: omni.replicator.isaac-2.0.8] startup
# [9.697s] [ext: omni.replicator.replicator_yaml-2.0.11] startup
# [9.714s] [ext: omni.rtx.settings.core-0.6.5] startup
# [9.720s] [ext: omni.usd.metrics.assembler.ui-107.3.1] startup
# [9.736s] [ext: omni.isaac.motion_generation-8.0.7] startup
# [9.739s] [ext: semantics.schema.editor-2.0.1] startup
# [9.746s] [ext: isaacsim.examples.extension-2.0.12] startup
# [9.749s] [ext: omni.kit.ui.actions-1.0.5] startup
# [9.754s] [ext: semantics.schema.property-2.0.1] startup
# [9.758s] [ext: omni.isaac.nucleus-1.0.6] startup
# [9.759s] [ext: omni.anim.curve.core-1.3.1] startup
# [9.781s] [ext: isaacsim.asset.importer.mjcf-2.5.8] startup
# [9.795s] [ext: isaacsim.examples.interactive-4.6.10] startup
# [9.817s] [ext: omni.kit.menu.common-2.0.0] startup
# [9.826s] [ext: isaacsim.exp.base-5.0.0] startup
# [9.829s] [ext: omni.kit.stage.copypaste-1.2.4] startup
# [9.837s] [ext: isaacsim.sensors.physics.ui-0.1.12] startup
# [9.845s] [ext: isaacsim.sensors.physics.examples-0.1.15] startup
# [9.856s] [ext: isaacsim.replicator.behavior.ui-1.0.5] startup
# [9.869s] [ext: omni.anim.curve.ui-1.4.1] startup
# [9.880s] [ext: isaacsim.robot.manipulators.ui-2.1.22] startup
# [9.881s] [ext: isaacsim.util.physics-1.1.5] startup
# [9.887s] [ext: omni.anim.curve.bundle-1.2.3] startup
# [9.888s] [ext: omni.kit.browser.asset-1.3.12] startup
# [9.891s] [ext: omni.anim.shared.core-107.0.1] startup
# [9.897s] [ext: isaacsim.robot.wheeled_robots.ui-2.1.23] startup
# [9.900s] [ext: isaacsim.asset.importer.heightmap-2.0.6] startup
# [9.906s] [ext: omni.graph.window.action-1.50.2] startup
# [9.919s] [ext: omni.simready.explorer-1.1.3] startup
# [9.933s] [ext: omni.importer.onshape-1.0.0] startup
# [9.950s] [ext: isaacsim.robot_setup.gain_tuner-3.0.5] startup
# [9.962s] [ext: omni.isaac.block_world-2.0.6] startup
# [9.965s] [ext: isaacsim.asset.gen.omap-2.0.28] startup
# [9.974s] [ext: isaacsim.robot_setup.grasp_editor-2.0.18] startup
# [9.980s] [ext: omni.isaac.extension_templates-2.0.7] startup
# [9.983s] [ext: omni.isaac.gain_tuner-2.0.5] startup
# [9.983s] [ext: isaacsim.sensors.physx.examples-2.2.15] startup
# [9.988s] [ext: omni.isaac.occupancy_map-2.0.8] startup
# [9.997s] [ext: omni.isaac.grasp_editor-2.0.7] startup
# [9.998s] [ext: isaacsim.sensors.rtx.ui-1.1.4] startup
# [10.002s] [ext: isaacsim.robot_setup.assembler-3.0.8] startup
# [10.010s] [ext: isaacsim.robot_setup.xrdf_editor-3.1.11] startup
# [10.015s] [ext: omni.isaac.range_sensor.examples-2.0.6] startup
# [10.018s] [ext: isaacsim.util.merge_mesh-2.0.15] startup
# [10.026s] [ext: isaacsim.replicator.scene_blox-1.0.8] startup
# [10.027s] [ext: isaacsim.replicator.synthetic_recorder-2.2.15] startup
# [10.034s] [ext: omni.isaac.robot_assembler-2.0.8] startup
# [10.036s] [ext: omni.isaac.robot_description_editor-3.0.5] startup
# [10.038s] [ext: isaacsim.asset.gen.omap.ui-2.2.1] startup
# [10.040s] [ext: omni.kit.actions.window-1.1.3] startup
# [10.050s] [ext: omni.isaac.scene_blox-1.0.6] startup
# [10.051s] [ext: omni.isaac.synthetic_recorder-2.0.6] startup
# [10.054s] [ext: omni.isaac.throttling-2.0.7] startup
# [10.057s] [ext: omni.kit.core.collection-0.2.3] startup
# [10.061s] [ext: omni.isaac.occupancy_map.ui-2.0.8] startup
# [10.063s] [ext: omni.kit.hotkeys.window-1.4.9] startup
# [10.076s] [ext: omni.kit.mesh.raycast-107.0.1] startup
# [10.082s] [ext: omni.kit.preferences.animation-1.2.0] startup
# [10.088s] [ext: omni.graph.bundle.action-2.30.0] startup
# [10.091s] [ext: omni.kit.property.collection-0.2.3] startup
# [10.095s] [ext: omni.mdl.usd_converter-1.0.30] startup
# [10.100s] [ext: omni.kit.property.layer-1.1.9] startup
# [10.104s] [ext: omni.kit.stagerecorder.core-107.0.3] startup
# [10.108s] [ext: omni.kit.search.files-1.0.4] startup
# [10.111s] [ext: omni.kit.browser.material-1.6.2] startup
# [10.116s] [ext: omni.kit.window.title-1.1.7] startup
# [10.118s] [ext: omni.kit.stage.mdl_converter-1.0.8] startup
# [10.120s] [ext: omni.kit.widgets.custom-1.0.13] startup
# [10.133s] [ext: omni.kit.stagerecorder.ui-107.0.1] startup
# [10.139s] [ext: omni.kit.tool.remove_unused.core-0.1.3] startup
# [10.142s] [ext: omni.kit.window.material-1.6.3] startup
# [10.151s] [ext: omni.kit.stage_column.payload-2.0.3] startup
# [10.154s] [ext: omni.kit.stage_column.variant-1.0.17] startup
# [10.159s] [ext: omni.kit.variant.editor-107.3.0] startup
# [10.176s] [ext: omni.kit.stagerecorder.bundle-105.0.2] startup
# [10.176s] [ext: omni.kit.tool.asset_exporter-4.0.4] startup
# [10.181s] [ext: omni.kit.tool.remove_unused.controller-0.1.4] startup
# [10.184s] [ext: omni.kit.usda_edit-1.1.18] startup
# [10.195s] [ext: omni.kit.widget.live-2.1.11] startup
# [10.198s] [ext: omni.kit.variant.presenter-107.0.0] startup
# [10.202s] [ext: omni.kit.viewport.bundle-104.0.1] startup
# [10.204s] [ext: omni.kit.widget.calendar-1.0.9] startup
# [10.206s] [ext: omni.kit.viewport.rtx-104.0.1] startup
# [10.207s] [ext: omni.kit.viewport_widgets_manager-1.0.9] startup
# [10.209s] [ext: omni.kit.widget.cache_indicator-3.0.6] startup
# [10.297s] [ext: omni.kit.property.physx-107.3.18] startup
# [10.332s] [ext: omni.physx.demos-107.3.18] startup
# [10.372s] [ext: omni.kit.widget.extended_searchfield-1.0.31] startup
# [10.387s] [ext: omni.kit.widget.schema_api-1.0.3] startup
# [10.391s] [ext: omni.asset_validator.core-1.1.6] startup
# [10.458s] [ext: omni.scene.optimizer.core-107.3.9] startup
# [10.534s] [ext: omni.usdex.libs-1.2.2] startup
# [10.551s] [ext: omni.physx.vehicle-107.3.18] startup
# [10.605s] [ext: omni.kit.window.commands-0.2.9] startup
# [10.633s] [ext: omni.kit.widget.timeline-107.0.1] startup
# [10.639s] [ext: omni.kit.window.script_editor-2.0.1] startup
# [10.646s] [ext: omni.asset_validator.ui-1.1.6] startup
# [10.673s] [ext: omni.physx.asset_validator-107.3.18] startup
# [10.896s] [ext: omni.kit.converter.common-506.3.1] startup
# [10.908s] [ext: isaacsim.sensors.physx.ui-2.2.12] startup
# [10.915s] [ext: omni.physx.camera-107.3.18] startup
# [10.933s] [ext: omni.physx.cct-107.3.18] startup
# [10.962s] [ext: omni.physx.graph-107.3.18] startup
# [10.998s] [ext: omni.physx.supportui-107.3.18] startup
# [11.034s] [ext: omni.physx.telemetry-107.3.18] startup
# [11.040s] [ext: omni.kit.converter.dgn_core-509.0.1] startup
# [11.118s] [ext: omni.isaac.range_sensor.ui-2.0.5] startup
# [11.123s] [ext: omni.kit.converter.hoops_core-508.0.2] startup
# [11.136s] [ext: omni.kit.converter.jt_core-507.0.1] startup
# [11.164s] [ext: omni.kit.window.usd_paths-1.0.8] startup
# [11.168s] [ext: omni.kit.widget.collection-0.3.1] startup
# [11.176s] [ext: omni.physx.bundle-107.3.18] startup
# [11.177s] [ext: omni.kit.converter.dgn-508.0.1] startup
# [11.184s] [ext: isaacsim.replicator.grasping-1.0.9] startup
# [11.994s] [ext: omni.kit.converter.hoops-508.0.1] startup
# [12.001s] [ext: omni.kit.converter.jt-507.0.1] startup
# [12.005s] [ext: omni.kit.quicklayout-1.0.8] startup
# [12.007s] [ext: omni.kit.window.collection-0.3.1] startup
# [12.010s] [ext: omni.isaac.physics_inspector-0.1.11] startup
# [12.011s] [ext: isaacsim.util.camera_inspector-1.0.15] startup
# [12.013s] [ext: isaacsim.replicator.grasping.ui-1.0.8] startup
# [12.020s] [ext: isaacsim.asset.validation-1.0.3] startup
# [12.054s] [ext: omni.kit.converter.cad-203.2.1] startup
# [12.055s] [ext: omni.kit.window.stats-0.1.7] startup
# [12.057s] [ext: isaacsim.app.setup-1.4.10] startup
# [12.058s] Isaac Sim Full Version: 5.0.0-rc.45
# [12.058s] Writing Isaac Sim icon file
# [12.059s] [ext: omni.kit.profiler.window-2.3.5] startup
# [12.065s] [ext: isaacsim.exp.full-5.0.0] startup
# [12.398s] [ext: isaacsim.ros2.bridge-4.9.3] startup
# [12.414s] Using backup internal ROS2 humble distro
# Checking to see if RMW can be loaded:
# failed to get symbol 'rmw_init_options_init' due to Environment variable 'AMENT_PREFIX_PATH' is not set or empty, at /workspace/humble_ws/src/rmw_implementation/src/functions.cpp:171, at /workspace/humble_ws/src/rcl/rcl/src/rcl/init_options.c:75
# RMW was not loaded
#
# [12.423s] To use the internal libraries included with the extension please set the following environment variables to use with FastDDS (default) or CycloneDDS before starting Isaac Sim:
#
# FastDDS (default):
# export ROS_DISTRO=humble
# export RMW_IMPLEMENTATION=rmw_fastrtps_cpp
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/isaacsim/exts/isaacsim.ros2.bridge/humble/lib
#
# OR
#
# CycloneDDS:
# export ROS_DISTRO=humble
# export RMW_IMPLEMENTATION=rmw_cyclonedds_cpp
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/isaacsim/exts/isaacsim.ros2.bridge/humble/lib
#
#
# [12.434s] [ext: isaacsim.ros2.bridge-4.9.3] shutdown
# 2025-10-31T03:19:09Z [12,407ms] [Error] [isaacsim.ros2.bridge.impl.extension] ROS2 Bridge startup failed
# [13.321s] [ext: omni.kit.registry.nucleus-0.0.0] startup
# 2025-10-31T03:19:10Z [13,654ms] [Error] [carb.graphics-vulkan.plugin] Could not get NGX parameters block because NGX isn't enabled.
# 2025-10-31T03:19:10Z [13,654ms] [Error] [carb.graphics-vulkan.plugin] Failed to create NGX context.
# 2025-10-31T03:19:10Z [13,774ms] [Error] [rtx.optixdenoising73.plugin] Failed to create an Optix adaptor for device 0
# [13.870s] app ready

# %%
import pxr


material = pxr.UsdShade.Material.Get(scene._usd_stage, "/World/Looks/theGrid")

# bool(material)
material.ComputeSurfaceSource("mdl")
material.ComputeSurfaceSource("")
# Out:
# (UsdShade.Shader(invalid null prim), '', pxr.UsdShade.AttributeType(32554))
